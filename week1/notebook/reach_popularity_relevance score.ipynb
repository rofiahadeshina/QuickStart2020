# %%
import pandas as pd


#top 100 influencers
top_100_handle = pd.read_csv('C:/Users/HP/Desktop/CV, P.Statement and others/10 Academy/Top_100influencer_handle.csv')
print(top_100_handle.head())

#government influencers
top_gov_handle = pd.read_csv(r'C:\Users\HP\Desktop\CV, P.Statement and others\10 Academy\gov_influencers_handles.csv')
print(top_gov_handle.head())

#joining the two
joint_handles = pd.read_csv(r'C:\Users\HP\Desktop\CV, P.Statement and others\10 Academy\final_handle.csv')
print(joint_handles.head())
# Out:
#          Handles
# 0     @gettleman
# 1      @a24media
# 2  @andiMakinana
# 3   @AfricaCheck
# 4  @JamesCopnall
#     Twitter Handles
# 0  @EswatiniGovern1
# 1       @MalawiGovt
# 2      @hagegeingob
# 3        @FinanceSC
# 4     @PresidencyZA
#    combined_handles
# 0  @EswatiniGovern1
# 1       @MalawiGovt
# 2      @hagegeingob
# 3        @FinanceSC
# 4     @PresidencyZA

# %%
#tweets for government and top influencers
influencer_tweets = pd.read_csv(r'C:\Users\HP\Desktop\CV, P.Statement and others\10 Academy\tweets.csv')
print(influencer_tweets.head())
# Out:
#    Unnamed: 0  \
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4
#
#                                                                                                                                  Influencer Tweets
# 0  Ministerial Statement: Minister of Health Lizzie Nkosi's #COVID19 update on 18 July 2020:\n\nNew cases: 110\nTotal cas… https://t.co/dPIOskAWte
# 1  Ministerial Statement: Minister of Health Lizzie Nkosi's #COVID19 update on 17 July 2020:\n\nNew cases: 67\nTotal case… https://t.co/s6s4AaumZ8
# 2  Minister of Health Lizzie Nkosi announces one new #COVID19 death in Eswatini, taking the total number of #COVID19 d… https://t.co/SX7Sfmulop
# 3  Ministerial Statement: Minister of Health Lizzie Nkosi's #COVID19 update on 15 July 2020:\n\nNew cases: 55\nTotal case… https://t.co/3Ge4J1KV9C
# 4  Ambassador Aragones: “When this project is implemented, it will run for the next eight months. It is earmarked to r… https://t.co/TFp9F4PE0d

# %%
# Out:
#    combined_handles
# 0  @EswatiniGovern1
# 1  @MalawiGovt
# 2  @hagegeingob
# 3  @FinanceSC
# 4  @PresidencyZA

# %%
#number of following
total_following = pd.read_csv(r'C:\Users\HP\Desktop\CV, P.Statement and others\10 Academy\final_following.csv')
print(total_following.head())
# Out:
#    Number of following
# 0                   82
# 1                   26
# 2                   55
# 3                  224
# 4                   14

# %%
gov_following= pd.read_csv('C:/Users/HP/Desktop/CV, P.Statement and others/10 Academy/gov_followings.csv')
print(gov_following.head())
# Out:
#    Unnamed: 0  Number of following
# 0           0                   82
# 1           1                   26
# 2           2                   55
# 3           3                  224
# 4           4                   14

# %%
inf_following = pd.read_csv('C:/Users/HP/Desktop/CV, P.Statement and others/10 Academy/inf_followings.csv')
print(inf_following.head())
# Out:
#    Unnamed: 0  Number of following
# 0           0                   37
# 1           1                 3059
# 2           2                 2838
# 3           3                 4592
# 4           4                 5050

# %%
#number of gov influencers followers
total_followers= pd.read_csv('C:/Users/HP/Desktop/CV, P.Statement and others/10 Academy/gov_follower.csv')
print(total_followers.head())
# Out:
#    Unnamed: 0  Number of followers
# 0           0                11324
# 1           1                39316
# 2           2               192482
# 3           3                  126
# 4           4              1599467

# %%
#number of top 100 influencers followers
totalinf_followers= pd.read_csv('C:/Users/HP/Desktop/CV, P.Statement and others/10 Academy/infl_follower.csv')
print(totalinf_followers.head())
# Out:
#    Unnamed: 0  Number of followers
# 0           0                25705
# 1           1                31286
# 2           2               101288
# 3           3                68073
# 4           4                21964

# %%
#number of gov+influencer followers
total_followers = pd.read_csv('C:/Users/HP/Desktop/CV, P.Statement and others/10 Academy/inf_gov_followers.csv')
print(total_followers.head())
# Out:
#    Number of followers
# 0  11321
# 1  39298
# 2  192437
# 3  126
# 4  1599121

# %%
#no of likes
likes = pd.read_csv(r'C:\Users\HP\Desktop\CV, P.Statement and others\10 Academy\final_likes.csv')
print(likes.head())
# Out:
#    No of likes
# 0           61
# 1          915
# 2          268
# 3           12
# 4           63

# %%
total_govlike=pd.read_csv('C:/Users/HP/Desktop/CV, P.Statement and others/10 Academy/gov_likes.csv')
print(total_govlike.head())
# Out:
#    Unnamed: 0  Number of likes
# 0           0               61
# 1           1              915
# 2           2              268
# 3           3               12
# 4           4               63

# %%
total_inflike=pd.read_csv('C:/Users/HP/Desktop/CV, P.Statement and others/10 Academy/infl_likes.csv')
print(total_inflike.head())
# Out:
#    Unnamed: 0  Number of likes
# 0  0           10
# 1  1           1621
# 2  2           9027
# 3  3           3916
# 4  4           3625

# %%
#no of retweets
retweets = pd.read_csv(r'C:\Users\HP\Desktop\CV, P.Statement and others\10 Academy\final#_retweets.csv')
print(retweets.head())
# Out:
#    No of retweets
# 0               0
# 1               0
# 2               1
# 3               1
# 4               0

# %%
#no of statuses
status = pd.read_csv(r'C:\Users\HP\Desktop\CV, P.Statement and others\10 Academy\final_statuses.csv')
print(status.head())
# Out:
#    No of statuses
# 0  1674
# 1  4030
# 2  1087
# 3  125
# 4  18881

# %%
final_gov_dataframe=pd.concat([top_gov_handle,gov_following,total_followers,total_govlike], axis=1)
print(final_gov_dataframe.head())
# Out:
#     Twitter Handles  Unnamed: 0  Number of following  Unnamed: 0  \
# 0  @EswatiniGovern1           0                   82           0
# 1       @MalawiGovt           1                   26           1
# 2      @hagegeingob           2                   55           2
# 3        @FinanceSC           3                  224           3
# 4     @PresidencyZA           4                   14           4
#
#    Number of followers  Unnamed: 0  Number of likes
# 0                11324           0               61
# 1                39316           1              915
# 2               192482           2              268
# 3                  126           3               12
# 4              1599467           4               63

# %%
final_gov_dataframe["score"] = final_gov_dataframe["Number of followers"]-final_gov_dataframe["Number of following"]
print(final_gov_dataframe)
# Out:
#      Twitter Handles  Unnamed: 0  Number of following  Unnamed: 0  \
# 0   @EswatiniGovern1           0                   82           0
# 1        @MalawiGovt           1                   26           1
# 2       @hagegeingob           2                   55           2
# 3         @FinanceSC           3                  224           3
# 4      @PresidencyZA           4                   14           4
# 5         @mohzambia           5                   95           5
# 6       @edmnangagwa           6                  116           6
# 7        @MinSantedj           7                  127           7
# 8           @hawelti           8                  435           8
# 9   @StateHouseKenya           9                  214           9
# 10       @PaulKagame          10                  181          10
# 11       @M_Farmaajo          11                    2          11
# 12    @SouthSudanGov          12                  463          12
# ...

# %%
final_dataframe = pd.concat([total_followers,total_following,likes,retweets,status], axis=1)
df = final_dataframe.dropna()
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-85426bf4bd69> in <module>
# ----> 1 final_dataframe = pd.concat([total_followers,total_following,likes,retweets,status], axis=1)
#       2 df = final_dataframe.dropna()
#       3 print(df.head())
#       4
#       5
#
# NameError: name 'status' is not defined

# %% [markdown]
# #### Popularity Score

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

popularity = pd.concat([retweets,likes,joint_handles],axis=1)
popularity["Score"] = popularity["No of retweets"]+popularity["No of likes"]
print(popularity)
# Out:
#       No of retweets  No of likes  combined_handles     Score
# 0     0               61.0         @EswatiniGovern1  61.0
# 1     0               915.0        @MalawiGovt       915.0
# 2     1               268.0        @hagegeingob      269.0
# 3     1               12.0         @FinanceSC        13.0
# 4     0               63.0         @PresidencyZA     63.0
# 5     0               163.0        @mohzambia        163.0
# 6     1257            65.0         @edmnangagwa      1322.0
# 7     0               587.0        @MinSantedj       587.0
# 8     0               733.0        @hawelti          733.0
# 9     0               61.0         @StateHouseKenya  61.0
# 10    1               616.0        @PaulKagame       617.0
# 11    0               22.0         @M_Farmaajo       22.0
# 12    0               348.0        @SouthSudanGov    348.0
# 13    0               43.0         @SudanPMHamdok    43.0
# 14    208             1.0          @TZSpokesperson   209.0
# ...

# %% [markdown]
# #### Reach Score

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

reach = pd.concat([joint_handles,total_followers,total_following],axis=1)
reach["score"]=reach["Number of followers"]-reach["Number of following"]
print(reach)
#reach.sort_values("score")
# Out:
#      combined_handles  Number of followers  Number of following       score
# 0    @EswatiniGovern1  11321.0              82.0                 11239.0
# 1    @MalawiGovt       39298.0              26.0                 39272.0
# 2    @hagegeingob      192437.0             55.0                 192382.0
# 3    @FinanceSC        126.0                224.0               -98.0
# 4    @PresidencyZA     1599121.0            14.0                 1599107.0
# 5    @mohzambia        7160.0               95.0                 7065.0
# 6    @edmnangagwa      546380.0             116.0                546264.0
# 7    @MinSantedj       2933.0               127.0                2806.0
# 8    @hawelti          66218.0              435.0                65783.0
# 9    @StateHouseKenya  1103903.0            214.0                1103689.0
# 10   @PaulKagame       1983882.0            181.0                1983701.0
# 11   @M_Farmaajo       424302.0             2.0                  424300.0
# ...
